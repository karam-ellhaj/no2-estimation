# %%
import pandas as pd 
import numpy as np
import warnings 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
train['Date'] = pd.to_datetime(train['Date'])
test['Date'] = pd.to_datetime(test['Date'])

# %%
train
# Out:
#         ID_Zindi       Date     ID        LAT        LON  Precipitation  \
# 0      ID_ENTGC7 2019-01-01   PD01  45.601585  11.903551       0.000000
# 1      ID_8JCCXC 2019-01-01   PD04  45.371005  11.840830       3.047342
# 2      ID_V3136Z 2019-01-01   RO01  45.045825  12.060869       0.000000
# 3      ID_KRVZDJ 2019-01-01   RO02  45.104075  11.553241       1.200467
# 4      ID_PR351A 2019-01-01   RO03  45.038758  11.790152       1.274564
# ...          ...        ...    ...        ...        ...            ...
# 86579  ID_NCWXIY 2021-12-31  X9897  45.498227   9.556232       0.000000
# 86580  ID_UDQIEE 2021-12-31  X9928  45.142541  10.043836       0.000000
# 86581  ID_ENDUPX 2021-12-31  X9969  45.842207   9.351658       0.000000
# 86582  ID_3ZBA6C 2021-12-31  X9993  45.113503   8.874065       0.000000
# 86583  ID_GWG0LD 2021-12-31  X9999  45.526473   9.515980       0.000000
#
#           LST       AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# ...

# %%
test
# Out:
#        ID_Zindi       Date     ID        LAT        LON  Precipitation  \
# 0     ID_2MYNQS 2019-01-01   PD03  45.289376  11.642394       3.277529
# 1     ID_P4U5WU 2019-01-01   TV03  45.836941  12.510362       0.000000
# 2     ID_U4KWPK 2019-01-01  X5561  45.582894   8.842165       0.000000
# 3     ID_QGSNTZ 2019-01-01  X5953  45.131947  10.015742       1.928031
# 4     ID_GHSZ6K 2019-01-01  X6701  45.186329   9.146666       0.000000
# ...         ...        ...    ...        ...        ...            ...
# 6571  ID_GUSXU9 2021-12-31   TV03  45.836941  12.510362       0.000000
# 6572  ID_GMVEG1 2021-12-31  X5561  45.582894   8.842165       0.000000
# 6573  ID_GD6HNP 2021-12-31  X5953  45.131947  10.015742       0.000000
# 6574  ID_J7YW1Y 2021-12-31  X6701  45.186329   9.146666       0.000000
# 6575  ID_I4E04N 2021-12-31  X6877  45.151743  10.781408       0.000000
#
#          LST       AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# ...

# %%
sns.lineplot(x=train['ID'],y=train['GT_NO2'])
# Out:
# <Axes: xlabel='ID', ylabel='GT_NO2'>

# %%
import numpy as np

# %%
train[['ID','GT_NO2']].groupby('ID')['GT_NO2'].std()
# Out:
# ID
# PD01      9.370354
# PD04     14.016305
# RO01     10.459017
# RO02      8.961198
# RO03     13.146802
#            ...
# X9897    14.883680
# X9928    13.375138
# X9969    13.325986
# X9993     8.841422
# X9999    17.765576
# Name: GT_NO2, Length: 79, dtype: float64

# %%
train[['Date','GT_NO2']].groupby('Date')['GT_NO2'].std()
# Out:
# Date
# 2019-01-01    10.127084
# 2019-01-02    18.339066
# 2019-01-03    14.204343
# 2019-01-04    16.032338
# 2019-01-05    10.173866
#                 ...
# 2021-12-27    12.975114
# 2021-12-28    10.268785
# 2021-12-29    10.494924
# 2021-12-30    12.071926
# 2021-12-31    13.892659
# Name: GT_NO2, Length: 1096, dtype: float64

# %%
train[['ID','GT_NO2']].groupby('ID')['GT_NO2'].std()
# Out:
# ID
# PD01      9.370354
# PD04     14.016305
# RO01     10.459017
# RO02      8.961198
# RO03     13.146802
#            ...
# X9897    14.883680
# X9928    13.375138
# X9969    13.325986
# X9993     8.841422
# X9999    17.765576
# Name: GT_NO2, Length: 79, dtype: float64

# %%
test
# Out:
#        ID_Zindi       Date     ID        LAT        LON  Precipitation  \
# 0     ID_2MYNQS 2019-01-01   PD03  45.289376  11.642394       3.277529
# 1     ID_P4U5WU 2019-01-01   TV03  45.836941  12.510362       0.000000
# 2     ID_U4KWPK 2019-01-01  X5561  45.582894   8.842165       0.000000
# 3     ID_QGSNTZ 2019-01-01  X5953  45.131947  10.015742       1.928031
# 4     ID_GHSZ6K 2019-01-01  X6701  45.186329   9.146666       0.000000
# ...         ...        ...    ...        ...        ...            ...
# 6571  ID_GUSXU9 2021-12-31   TV03  45.836941  12.510362       0.000000
# 6572  ID_GMVEG1 2021-12-31  X5561  45.582894   8.842165       0.000000
# 6573  ID_GD6HNP 2021-12-31  X5953  45.131947  10.015742       0.000000
# 6574  ID_J7YW1Y 2021-12-31  X6701  45.186329   9.146666       0.000000
# 6575  ID_I4E04N 2021-12-31  X6877  45.151743  10.781408       0.000000
#
#          LST       AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# ...

# %%
sns.displot(train['GT_NO2'])

# %%
sns.distplot(train['GT_NO2'])
# Out:
# <Axes: xlabel='GT_NO2', ylabel='Density'>

# %%
train[~train['GT_NO2'].isna()]
# Out:
#         ID_Zindi       Date     ID        LAT        LON  Precipitation  \
# 0      ID_ENTGC7 2019-01-01   PD01  45.601585  11.903551       0.000000
# 1      ID_8JCCXC 2019-01-01   PD04  45.371005  11.840830       3.047342
# 2      ID_V3136Z 2019-01-01   RO01  45.045825  12.060869       0.000000
# 3      ID_KRVZDJ 2019-01-01   RO02  45.104075  11.553241       1.200467
# 4      ID_PR351A 2019-01-01   RO03  45.038758  11.790152       1.274564
# ...          ...        ...    ...        ...        ...            ...
# 86579  ID_NCWXIY 2021-12-31  X9897  45.498227   9.556232       0.000000
# 86580  ID_UDQIEE 2021-12-31  X9928  45.142541  10.043836       0.000000
# 86581  ID_ENDUPX 2021-12-31  X9969  45.842207   9.351658       0.000000
# 86582  ID_3ZBA6C 2021-12-31  X9993  45.113503   8.874065       0.000000
# 86583  ID_GWG0LD 2021-12-31  X9999  45.526473   9.515980       0.000000
#
#           LST       AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# ...

# %%
test
# Out:
#        ID_Zindi       Date     ID        LAT        LON  Precipitation  \
# 0     ID_2MYNQS 2019-01-01   PD03  45.289376  11.642394       3.277529
# 1     ID_P4U5WU 2019-01-01   TV03  45.836941  12.510362       0.000000
# 2     ID_U4KWPK 2019-01-01  X5561  45.582894   8.842165       0.000000
# 3     ID_QGSNTZ 2019-01-01  X5953  45.131947  10.015742       1.928031
# 4     ID_GHSZ6K 2019-01-01  X6701  45.186329   9.146666       0.000000
# ...         ...        ...    ...        ...        ...            ...
# 6571  ID_GUSXU9 2021-12-31   TV03  45.836941  12.510362       0.000000
# 6572  ID_GMVEG1 2021-12-31  X5561  45.582894   8.842165       0.000000
# 6573  ID_GD6HNP 2021-12-31  X5953  45.131947  10.015742       0.000000
# 6574  ID_J7YW1Y 2021-12-31  X6701  45.186329   9.146666       0.000000
# 6575  ID_I4E04N 2021-12-31  X6877  45.151743  10.781408       0.000000
#
#          LST       AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# ...

# %%
train
# Out:
#         ID_Zindi       Date     ID        LAT        LON  Precipitation  \
# 0      ID_ENTGC7 2019-01-01   PD01  45.601585  11.903551       0.000000
# 1      ID_8JCCXC 2019-01-01   PD04  45.371005  11.840830       3.047342
# 2      ID_V3136Z 2019-01-01   RO01  45.045825  12.060869       0.000000
# 3      ID_KRVZDJ 2019-01-01   RO02  45.104075  11.553241       1.200467
# 4      ID_PR351A 2019-01-01   RO03  45.038758  11.790152       1.274564
# ...          ...        ...    ...        ...        ...            ...
# 86579  ID_NCWXIY 2021-12-31  X9897  45.498227   9.556232       0.000000
# 86580  ID_UDQIEE 2021-12-31  X9928  45.142541  10.043836       0.000000
# 86581  ID_ENDUPX 2021-12-31  X9969  45.842207   9.351658       0.000000
# 86582  ID_3ZBA6C 2021-12-31  X9993  45.113503   8.874065       0.000000
# 86583  ID_GWG0LD 2021-12-31  X9999  45.526473   9.515980       0.000000
#
#           LST       AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# ...

# %%
train[['Date','GT_NO2']].groupby('Date')['GT_NO2'].std()
# Out:
# Date
# 2019-01-01    10.127084
# 2019-01-02    18.339066
# 2019-01-03    14.204343
# 2019-01-04    16.032338
# 2019-01-05    10.173866
#                 ...
# 2021-12-27    12.975114
# 2021-12-28    10.268785
# 2021-12-29    10.494924
# 2021-12-30    12.071926
# 2021-12-31    13.892659
# Name: GT_NO2, Length: 1096, dtype: float64

# %%
plt.figure(figsize=(25,10))
sns.lineplot(x=train['Date'],y=train['GT_NO2'])
# Out:
# <Axes: xlabel='Date', ylabel='GT_NO2'>

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(train.select_dtypes(include='number').corr(),annot=(train.select_dtypes(include='number').corr()))
# Out:
# <Axes: >

# %%
train = train[train['GT_NO2']<120]

# %%
sns.scatterplot(x=train['NO2_total'],y=train['NO2_trop'],hue=train['GT_NO2'])
# Out:
# <Axes: xlabel='NO2_total', ylabel='NO2_trop'>

# %%
sns.scatterplot(x=train['GT_NO2'],y=train['NO2_total'])
# Out:
# <Axes: xlabel='GT_NO2', ylabel='NO2_total'>

# %%
sns.scatterplot(x=train['GT_NO2'],y=(train['NO2_trop']/train['NO2_total']))
# Out:
# <Axes: xlabel='GT_NO2'>

# %%
sns.scatterplot(x=train['GT_NO2'],y=train['NO2_trop'])
# Out:
# <Axes: xlabel='GT_NO2', ylabel='NO2_trop'>

# %%
train
# Out:
#         ID_Zindi       Date     ID        LAT        LON  Precipitation  \
# 0      ID_ENTGC7 2019-01-01   PD01  45.601585  11.903551       0.000000
# 1      ID_8JCCXC 2019-01-01   PD04  45.371005  11.840830       3.047342
# 2      ID_V3136Z 2019-01-01   RO01  45.045825  12.060869       0.000000
# 3      ID_KRVZDJ 2019-01-01   RO02  45.104075  11.553241       1.200467
# 4      ID_PR351A 2019-01-01   RO03  45.038758  11.790152       1.274564
# ...          ...        ...    ...        ...        ...            ...
# 86579  ID_NCWXIY 2021-12-31  X9897  45.498227   9.556232       0.000000
# 86580  ID_UDQIEE 2021-12-31  X9928  45.142541  10.043836       0.000000
# 86581  ID_ENDUPX 2021-12-31  X9969  45.842207   9.351658       0.000000
# 86582  ID_3ZBA6C 2021-12-31  X9993  45.113503   8.874065       0.000000
# 86583  ID_GWG0LD 2021-12-31  X9999  45.526473   9.515980       0.000000
#
#           LST       AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# ...

# %%
test
# Out:
#        ID_Zindi       Date     ID        LAT        LON  Precipitation  \
# 0     ID_2MYNQS 2019-01-01   PD03  45.289376  11.642394       3.277529
# 1     ID_P4U5WU 2019-01-01   TV03  45.836941  12.510362       0.000000
# 2     ID_U4KWPK 2019-01-01  X5561  45.582894   8.842165       0.000000
# 3     ID_QGSNTZ 2019-01-01  X5953  45.131947  10.015742       1.928031
# 4     ID_GHSZ6K 2019-01-01  X6701  45.186329   9.146666       0.000000
# ...         ...        ...    ...        ...        ...            ...
# 6571  ID_GUSXU9 2021-12-31   TV03  45.836941  12.510362       0.000000
# 6572  ID_GMVEG1 2021-12-31  X5561  45.582894   8.842165       0.000000
# 6573  ID_GD6HNP 2021-12-31  X5953  45.131947  10.015742       0.000000
# 6574  ID_J7YW1Y 2021-12-31  X6701  45.186329   9.146666       0.000000
# 6575  ID_I4E04N 2021-12-31  X6877  45.151743  10.781408       0.000000
#
#          LST       AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# ...

# %%
for df in (train,test):
    df['Date'] = pd.to_datetime(df['Date'])
    df['day'] = df['Date'].dt.day
    df['dayweek'] = df['Date'].dt.weekday
    df['day_of_year'] = df['Date'].dt.dayofyear
    df['month'] = df['Date'].dt.month
    df['year'] = df['Date'].dt.year

# %%
sns.lineplot(y=train['GT_NO2'],x=train['dayweek'])
# Out:
# <Axes: xlabel='dayweek', ylabel='GT_NO2'>

# %%
sns.lineplot(y=train['GT_NO2'],x=train['day_of_year'])
# Out:
# <Axes: xlabel='day_of_year', ylabel='GT_NO2'>

# %%
sns.lineplot(y=train['GT_NO2'],x=train['day'])
# Out:
# <Axes: xlabel='day', ylabel='GT_NO2'>

# %%
sns.scatterplot(x=train['LAT'],y=train['LON'],hue=train['GT_NO2'])
# Out:
# <Axes: xlabel='LAT', ylabel='LON'>

# %%
sns.scatterplot(x=train['NO2_strat'],y=train['NO2_total'],hue=train['GT_NO2'])
# Out:
# <Axes: xlabel='NO2_strat', ylabel='NO2_total'>

# %%
train.head(3)
# Out:
#     ID_Zindi       Date    ID        LAT        LON  Precipitation  LST  \
# 0  ID_ENTGC7 2019-01-01  PD01  45.601585  11.903551       0.000000  NaN
# 1  ID_8JCCXC 2019-01-01  PD04  45.371005  11.840830       3.047342  NaN
# 2  ID_V3136Z 2019-01-01  RO01  45.045825  12.060869       0.000000  NaN
#
#         AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# 0  0.230527       0.559117   0.000024   0.000117       NaN
# 1 -0.074006       0.869309   0.000024   0.000127       NaN
# 2  0.024470       0.674160   0.000024   0.000086       NaN
#
#    TropopausePressure  GT_NO2  day  dayweek  day_of_year  month  year
# 0         14440.82126    31.0    1        1            1      1  2019
# 1         14441.79815    42.0    1        1            1      1  2019
# 2         14437.38294    31.0    1        1            1      1  2019

# %%
sns.lineplot(y=train['GT_NO2'],x=train['month'])
# Out:
# <Axes: xlabel='month', ylabel='GT_NO2'>

# %%
sns.lineplot(y=train['GT_NO2'],x=train['year'])
# Out:
# <Axes: xlabel='year', ylabel='GT_NO2'>

# %%
sns.scatterplot(y=train['GT_NO2'],x=train['LON'])
# Out:
# <Axes: xlabel='LON', ylabel='GT_NO2'>
